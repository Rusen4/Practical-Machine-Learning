# %% [markdown]
# # **Task 1 Import Dataset**

# %%
import pandas as pd
df = pd.read_csv("Loan.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # **Task 2 Exploratory data analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# 1. Loan ID จะเป็นตัวแปรที่ระบุไอดีของผู้กู้ยืมแต่ละราย <br>
# 2. Gender จะเป็นตัวแปรที่ระบุเพศของผู้กู้ยืม <br>
# 3. Married จะเป็นตัวแปรที่ระบุสถานะการแต่งงานของผู้กู้ยืม <br>
# 4. Dependents จะเป็นตัวแปรที่ระบุจำนวนผู้อยู่ในอุปการะของผู้กู้ยืม <br>
# 5. Education จะเป็นตัวแปรที่ระบุระดับการศึกษาของผู้กู้ยืมว่าจบการศึกษาหรือไม่ <br>
# 6. Self Employed จะเป็นตัวแปรที่ระบุว่าผู้กู้ยืมเป็นเจ้าของกิจการหรือไม่ <br>
# 7. Applicant Income <br>
# 8. Coapplicant Income <br>
# 9. Loan Amount Term <br>
# 10. Credit History จะเป็นตัวแปรที่่บอกถึงประวัติการยืมของผู้กู้ยืม <br>
# 11. Property Area จะเป็นตัวแปรที่บอกว่าผู้กู้ยืมอยู่พื้นที่ใด ซึ่งจะมี urban, semiurban, rural <br>
# 12. Loan Status จะเป็นตัวแปรที่ระบุว่าผู้กู้ยืมได้รับการอนุมัติให้กู้ยืมหรือไม่ <br>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df['Gender'].value_counts(normalize=True).plot.bar(figsize=(15, 8), title='Gender value counts')
plt.xlabel('Gender')
plt.ylabel('Value counts')
plt.show()
df['Married'].value_counts(normalize=True).plot.bar(title="Married value counts")
plt.xlabel('Married')
plt.ylabel('Value counts')
plt.show()
df['Self_Employed'].value_counts(normalize=True).plot.bar(title='Self_Employed value counts')
plt.xlabel('Self_Employed')
plt.ylabel('Value counts')
plt.show()
df['Credit_History'].value_counts(normalize=True).plot.bar(title='Credit_History value counts')
plt.xlabel('Credit History')
plt.ylabel('Value counts')
plt.show()

# %% [markdown]
# จากกราฟด้านบนโชว์ให้เห็นว่า... <br>
# 1) 80% ของผู้กู้ยืมในข้อมูลชุดนี้คือเพศชาย <br>
# 2) ประมาณ 65% ของผู้กู้ยืมนั้นแต่งงานแล้ว <br>
# 3) ประมาณ 15% ของผู้กู้ยืมนั้นเป็น self-employed ส่วนอีก 85% เป็น not self-employed <br>
# 4) ประมาณ 85% ของผู้กู้ยืมนั้นจ่ายหนี้ของเขา(สังเกตได้จาก Credit_History เท่ากับ 1) <br>

# %%
df['Dependents'].value_counts(normalize=True).plot.bar(figsize=(15 ,5),title='Dependents value counts')
plt.xlabel('Dependents')
plt.ylabel('Value counts')
plt.show()
df['Education'].value_counts(normalize=True).plot.bar(title='Education value counts')
plt.xlabel('Education')
plt.ylabel('Value counts')
plt.show()
df['Property_Area'].value_counts(normalize=True).plot.bar(title='Property Area value counts')
plt.xlabel('Property Area')
plt.ylabel('Value counts')
plt.show()

# %% [markdown]
# จากกราฟด้านบนแสดงให้เห็นว่า... <br>
# 1) ผู้กู้ยืมส่วนใหญ่ไม่มีผู้อยุ่ในอุปการะ <br>
# 2) ประมาณ 80% ของผู้กู้ยืมนั้นจบการศึกษา <br>
# 3) ผู้กู้ยืมส่วนใหญ่นั้นมาจาก semi-urban <br>

# %%
gender = pd.crosstab(df['Gender'], df['Loan_Status'])
gender.div(gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(8, 8))
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# จากกราฟด้าน Gender ด้านบนนั้นแสดงให้เห็นว่าเพศไม่มีอิทธิพลต่อการกู้ยืม

# %%
married  = pd.crosstab(df['Married'], df['Loan_Status'])
married.div(married.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(7,7))
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# จากกราฟ Married ด้านบนแสดงให้เห็นว่าผู้กู้ยืมที่แต่งงานแล้วจะได้รับการอนุมัติการกู้ยืมมากกว่าผู้ที่ยังไม่แต่งงาน

# %%
dependents  = pd.crosstab(df['Dependents'], df['Loan_Status'])
dependents.div(dependents.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(7,7))
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# จากกราฟ Dependents ด้านบนแสดงให้เห็นว่าผู้กู้ยืมที่มีผู้อยู่ในอุปการะสองคน จะได้รับการอนุมัติการกู้ยืมมากกว่า

# %%
education  = pd.crosstab(df['Education'], df['Loan_Status'])
education.div(education.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(7,7))
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# จากกราฟ Education ด้านบนแสดงให้เห็นว่าผู้ที่จบการศึกษาจะได้รับการอนุมัติการกู้ยืมมากว่า

# %%
self_employed  = pd.crosstab(df['Self_Employed'], df['Loan_Status'])
self_employed.div(self_employed.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(7,7))
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# จากกราฟ Self_Employed ด้านบนนั้นไม่มีความแตกต่างระหว่าง not Self-employed กับ Self-employed

# %%
credit =pd.crosstab(df['Credit_History'],df['Loan_Status'])
credit.div(credit.sum(1).astype(float), axis=0).plot(kind="bar",stacked=True,figsize=(6,6))
plt.ylabel('Percentage')
plt.show()

# %%
area =pd.crosstab(df['Property_Area'],df['Loan_Status'])
area.div(area.sum(1).astype(float), axis=0).plot(kind="bar",stacked=True,figsize=(6,6))
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# จากกราฟ Property_Area ด้านบนแสดงให้เห็นว่าผู้กู้ยืมจาก Semi-urban ได้รับการอนุมัติการกู้ยืมมากที่สุด

# %% [markdown]
# # **Task 3 Handling Missing values**

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# จากโค้ดด้านบนจะเห็นว่ามีตัวแปรที่มีค่า Null อยู่ 7 ตัวคือ <br>
# 1)Gender, 2)Married, 3)Dependents, 4)Self_Employed, 5)LoanAmount, 6)Loan_Amount_Term และ 7)Credit_History

# %%
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
df['Married'].fillna(df['Married'].mode()[0], inplace=True)
df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0], inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mode()[0], inplace=True)

# %% [markdown]
# จากโค้ดด้านบนจะเป็นการจัดการค่า Null ของ Categorical variables

# %%
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0], inplace=True)
df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)

# %% [markdown]
# จากโค้ดด้านบนจะเป็นการจัดการค่า Null ของ Numerical variables

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df['TotalIncome'] = df['ApplicantIncome'] + df['CoapplicantIncome']

# %% [markdown]
# จากโค้ดด้านบนทำการสร้างตัวแปรใหม่ที่มีชื่อว่า TotalIncome เนื่องจาก Income ของผู้กู้ยืมถูกแยกออกเป็นสองส่วนคือ ApplicantIncome และ CoApplicantIncome

# %%
df['TotalIncome'].describe()
# Out:
# count      614.000000
# mean      7024.705081
# std       6458.663872
# min       1442.000000
# 25%       4166.000000
# 50%       5416.500000
# 75%       7521.750000
# max      81000.000000
# Name: TotalIncome, dtype: float64

# %%
bins=[0,2500,4000,6000,81000]
group=['Low', 'Average', 'High', 'Very High']
df['Total_Income_bin']=pd.cut(df['TotalIncome'],bins,labels=group)
Total_Income_bin=pd.crosstab(df['Total_Income_bin'],df['Loan_Status'])
Total_Income_bin.div(Total_Income_bin.sum(1).astype(float), axis=0).plot(kind="bar",stacked=True)
plt.xlabel('TotalIncome')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# จากกราฟด้านบนแสดงให้เห็นว่าผู้กู้ยืมเงินที่มีรายได้สุทธิน้อย ประมาณร้อยละ 60 จะไม่ถูกอนุมัติการกู้ยืมเงิน

# %%
sns.distplot(df.TotalIncome)
# Out:
# <AxesSubplot:xlabel='TotalIncome'>

# %% [markdown]
# จากกราฟด้านบนจะเห็นว่ากราฟนั้นเบ้ขวา โค้ดด้านล่างจึงทำการสเกลตัวแปร TotalIncome ด้วย log ฟังก์ชัน เพื่อทำให้อยู๋ในรูปกราฟระฆังคว่ำ(bell curve)

# %%
df['TotalIncome_log'] = np.log(df['TotalIncome'])
sns.distplot(df.TotalIncome_log)
# Out:
# <AxesSubplot:xlabel='TotalIncome_log'>

# %%
df[['Gender', 'TotalIncome']].groupby(['Gender'], 
    as_index=False).mean().sort_values(by='TotalIncome', ascending=False)
# Out:
#    Gender  TotalIncome
# 1    Male  7308.770757
# 0  Female  5751.482143

# %%
df[['Married', 'TotalIncome']].groupby(['Married'],
    as_index=False).mean().sort_values(by='TotalIncome', ascending=False)
# Out:
#   Married  TotalIncome
# 1     Yes  7416.583342
# 0      No  6286.943662

# %%
df[['Dependents', 'TotalIncome']].groupby(['Dependents'],
    as_index=False).mean().sort_values(by='TotalIncome', ascending=False)
# Out:
#   Dependents   TotalIncome
# 3         3+  10605.529412
# 1          1   7388.509804
# 2          2   6614.027723
# 0          0   6529.561444

# %%
df[['Education', 'TotalIncome']].groupby(['Education'],
    as_index=False).mean().sort_values(by='TotalIncome', ascending=False)
# Out:
#       Education  TotalIncome
# 0      Graduate  7574.908167
# 1  Not Graduate  5053.828358

# %%
df = df.drop(['ApplicantIncome', 'CoapplicantIncome'], axis=1)

# %% [markdown]
# จากโค้ดด้านบนได้ทำการdrop คอลัมน์ ApplicantIncome

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History',
#        'Property_Area', 'Loan_Status', 'TotalIncome', 'Total_Income_bin',
#        'TotalIncome_log'],
#       dtype='object')
# (614, 14)

# %% [markdown]
# # **Task 4 Handling Categorical Variables**

# %%
#Loan Status Encoding
df['Loan_Status'] = df.Loan_Status.map({'Y':1, 'N':0}).astype(int)

#Gender Encoding
df = df.replace({"Gender":{"Male":1, "Female":0}})

#Married Encoding
df = df.replace({"Married" :{"Yes":1, "No":0}})

#Replace 3+ to dependents and make this column to numeric
df['Dependents'] = df['Dependents'].replace('3+', 3)
df['Dependents'] = pd.to_numeric(df['Dependents'], errors='coerce')

#Self_Employed Encoding
df = df.replace({"Self_Employed": {"Yes":1, "No":0}})

#Education Encoding
df = df.replace({"Education":{"Graduate":1, "Not Graduate":0}})

#Property Area Encoding
df['Property_Area'] = df['Property_Area'].map({'Rural':0, 'Urban':1, 'Semiurban':2})

# %%
df
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        0           0          1              0
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              1
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        0           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       0        0           0          1              1
#
#      LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status  \
# ...

# %% [markdown]
# # **Task 5 Feature Selection**

# %%
df = df.drop(['Loan_ID', 'Total_Income_bin'], axis=1)
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  LoanAmount  \
# 0         1        0           0          1              0       128.0
# 1         1        1           1          1              0       128.0
# 2         1        1           0          1              1        66.0
# 3         1        1           0          0              0       120.0
# 4         1        0           0          1              0       141.0
# ..      ...      ...         ...        ...            ...         ...
# 609       0        0           0          1              0        71.0
# 610       1        1           3          1              0        40.0
# 611       1        1           1          1              0       253.0
# 612       1        1           2          1              0       187.0
# 613       0        0           0          1              1       133.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status  \
# ...

# %%
X = df.drop('Loan_Status',axis=1)
y = df.Loan_Status

from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X,y)
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
from sklearn.feature_selection import RFE

rfe = RFE(RandomForestClassifier(n_estimators=100, random_state=42), n_features_to_select=5)
rfe.fit(X, y)
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False False False False False  True  True  True False  True  True]
# [7 4 2 5 6 1 1 1 3 1 1]

# %%
features_selected = np.asarray(X.columns)[rfe.get_support()]
print(features_selected)
# Out:
# ['LoanAmount' 'Loan_Amount_Term' 'Credit_History' 'TotalIncome'
#  'TotalIncome_log']

# %% [markdown]
# # **Task 6 Build a model**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
X_scale = scaler.fit_transform(X)

kfold = KFold(n_splits=5, shuffle=True, random_state=42)
forest = RandomForestClassifier(n_estimators=100, max_depth=13)


X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size=0.3, random_state=0)

forest.fit(X_train, y_train)
y_pred = forest.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print("Confusion-matrix:\n{}".format(cm))

acc = cross_val_score(forest, X_train, y_train, cv=kfold)
print("RandomForestClassifier Cross-validation scores:\n{}".format(acc))
print("RandomForestClassifier Cross-validation scores:{:.2f}".format(acc.mean()))
# Out:
# Confusion-matrix:
# [[ 22  29]
#  [  9 125]]
# RandomForestClassifier Cross-validation scores:
# [0.75581395 0.76744186 0.80232558 0.79069767 0.74117647]
# RandomForestClassifier Cross-validation scores:0.77
